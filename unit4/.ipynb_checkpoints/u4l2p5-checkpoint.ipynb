# %%
import numpy as np
import pandas as pd
import scipy
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

from sklearn.cluster import KMeans, MeanShift, estimate_bandwidth, SpectralClustering, AffinityPropagation
from sklearn.preprocessing import normalize
from sklearn.model_selection import train_test_split
from sklearn.decomposition import PCA
from sklearn import metrics
sns.set(context='talk',style='darkgrid', palette='mako_r')

# %%
data_path = ("https://raw.githubusercontent.com/llimllib/bostonmarathon/master/results/2014/results.csv")
df = pd.read_csv(data_path)

# %%
df.shape
# Out:
# (31984, 21)

# %%
null = df.isnull().sum()
null[null>0]
# Out:
# ctz      30740
# state     2576
# city         1
# dtype: int64

# %%
df.drop(['ctz','state'],axis=1,inplace=True)
df.dropna(inplace=True)

# %%
df.describe()
# Out:
#            division           age      official     genderdiv       overall  \
# count  31983.000000  31983.000000  31983.000000  31983.000000  31983.000000
# mean    1932.615858     42.406716    242.997837   8051.148579  15939.640340
# std     1715.229489     11.316488     52.301165   4754.043678   9233.117792
# min        1.000000     18.000000     80.600000      1.000000      1.000000
# 25%      610.000000     33.000000    205.525000   3972.000000   7943.500000
# 50%     1425.000000     42.000000    232.370000   7970.000000  15940.000000
# 75%     2611.000000     50.000000    273.240000  11968.000000  23935.500000
# max     6979.000000     81.000000    538.880000  17575.000000  31931.000000
#
#                pace
# count  31983.000000
# mean       9.275678
# std        1.992514
# min        3.080000
# 25%        7.850000
# 50%        8.870000
# 75%       10.430000
# max       20.570000

# %%
df.head()
# Out:
#      10k                name  division    25k gender  age  official bib  \
# 0  17.37  Yamamoto, Hiroyuki         8  47.67      M   47     85.25  W1
# 1  32.58        Jeptoo, Rita         1  82.43      F   33    138.95  F1
# 2  16.62   Van Dyk, Ernst F.         1  45.80      M   41     80.60  W2
# 3  32.57        Dibaba, Mare         3  82.43      F   24    140.58  F2
# 4  17.12      Hokinoue, Kota         2  46.37      M   40     81.23  W3
#
#    genderdiv     35k  overall  pace    30k     5k   half    20k country  \
# 0          8   71.40        8  3.27  59.18   8.02  39.72  37.65     JPN
# 1          1  116.37       21  5.30  99.33  16.22  69.47  65.83     KEN
# 2          1   67.42        1  3.08  56.45   7.75  38.03  36.10     RSA
# 3          3  116.37       27  5.37  99.33  16.20  69.47  65.83     ETH
# 4          2   67.83        2  3.10  57.03   8.02  38.60  36.58     JPN
#
#              city     40k
# 0         Fukuoka   80.43
# 1         Eldoret  132.10
# 2           Paarl   76.10
# 3            Shoa  132.95
# 4  Nogata Fukuoka   76.72

# %%
cols_to_num = ['10k','25k','35k','30k','5k','half','20k','40k']
for col in cols_to_num:
    df[col] = df[col].str.replace('-','')
    df[col] = pd.to_numeric(df[col])

# %%
df.isnull().sum()
# Out:
# 10k           50
# name           0
# division       0
# 25k          216
# gender         0
# age            0
# official       0
# bib            0
# genderdiv      0
# 35k           34
# overall        0
# pace           0
# 30k           40
# 5k            52
# half          72
# 20k           51
# country        0
# city           0
# 40k           39
# dtype: int64

# %%
df.dropna(inplace=True)

# %%
countries = df.groupby('country')['official','age','overall','genderdiv'].mean()
df['countme'] = 1
countries['parts'] = df.groupby('country')['countme'].sum()
countries.reset_index(inplace=True)
countries.head()
# Out:
#   country    official        age       overall    genderdiv  parts
# 0     ARG  207.736000  43.333333   8800.000000  4688.800000     15
# 1     AUS  223.861220  44.414634  12267.414634  6734.146341    123
# 2     AUT  251.453333  49.952381  18181.095238  9898.666667     21
# 3     BAH  270.550000  45.000000  23049.500000  9647.500000      2
# 4     BAR  256.120000  46.000000  21166.000000  8677.000000      1

# %%
plt.figure(figsize=(9,6))
sns.barplot(x='parts',y='country',data=countries.sort_values(by='parts',ascending=False)[2:14],palette='mako_r')
plt.title('Participants by country (ex USA, can)')
plt.xlabel('Participants')
# Out:
# Text(0.5, 0, 'Participants')

# %%
plt.figure(figsize=(9,6))
sns.barplot(x='official',y='country',data=countries[countries.parts > 25].sort_values(by='official')[:12],palette='mako')
plt.title('Average finish times by country (emin 25 participants)')
plt.xlabel('official time')
plt.show()

# %%
plt.figure(figsize=(9,6))
sns.distplot(df.age)
plt.title('Distribution of participant age')
plt.show()
# Out:
# C:\Users\godwinz\AppData\Local\Continuum\anaconda3\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
plt.figure(figsize=(9,6))
sns.distplot(countries['age'],kde=False)
plt.title("Distribution of countries by average age of participants")
# Out:
# Text(0.5, 1.0, 'Distribution of countries by average age of participants')

# %%
df.gender = np.where(df.gender == 'M',1,0)

# %%
df.country = df.country.astype('category')
df.country = df.country.cat.codes

# %%
data = df.drop(['name','bib','city','countme'],axis=1)

# %%
data_norm = normalize(data)

# %%
#split the data
X1, X2, X3, X4 = np.array_split(data_norm, 4)
Xs = [X1,X2,X3,X4]

# %%
#all data
clusters = [2,4,9,16,25,36,49]
for i in clusters:
    print("Number of defined clusters: {}".format(i))
    for j in Xs:
        model = KMeans(n_clusters=i, random_state=None).fit(j)
        labels = model.labels_
        print(metrics.silhouette_score(j, labels, metric='euclidean'))
# Out:
# Number of defined clusters: 2
# 0.6344528035587395
# 0.6763265565857736
# 0.5478162245139571
# 0.48995061751132957
# Number of defined clusters: 4
# 0.6067538845849694
# 0.6117516843244218
# 0.628262030180075
# 0.7096587094745834
# Number of defined clusters: 9
# 0.5171124920865771
# 0.45742744036503097
# 0.4952948869746322
# 0.6920090657360498
# Number of defined clusters: 16
# 0.4528861890154254
# 0.4595619803339629
# 0.47216170283143494
# 0.6037642748552627
# Number of defined clusters: 25
# 0.45181883002620665
# 0.46454315652754324
# 0.4902826467247312
# 0.5815858016925508
# Number of defined clusters: 36
# 0.4461748487627152
# 0.4684815748110296
# 0.4820153017102389
# 0.5434679296519256
# Number of defined clusters: 49
# 0.44987852345169255
# 0.4807939545222647
# 0.491114984412639
# 0.5316474429732666

# %%
#all data
for i in Xs:    
    bandwidth = estimate_bandwidth(i, quantile=0.2, n_samples=500)
    ms = MeanShift(bandwidth=bandwidth, bin_seeding=True)
    ms.fit(i)    
    labels = ms.labels_ # Extract cluster assignments for each data point.   
    cluster_centers = ms.cluster_centers_  # Coordinates of the cluster centers.    
    n_clusters_ = len(np.unique(labels)) # Count our clusters.
    print("Number of estimated clusters: {}".format(n_clusters_)) 
    print(metrics.silhouette_score(i, labels, metric='euclidean'))
# Out:
# Number of estimated clusters: 5
# 0.5940614469131957
# Number of estimated clusters: 5
# 0.4143307010961607
# Number of estimated clusters: 4
# 0.5974116909302416
# Number of estimated clusters: 5
# 0.7258355084629203

# %%
clusters = [4,9,16]
for i in clusters:
    print("Number of defined clusters: {}".format(i))
    for j in Xs:
        sc = SpectralClustering(n_clusters=i)
        sc.fit(j)
        labels = sc.labels_
        print(metrics.silhouette_score(j, labels, metric='euclidean'))
# Out:
# Number of defined clusters: 4
# 0.5847848761943617
# 0.3677845031288648
# 0.5757674577502591
# 0.6036183337287885
# Number of defined clusters: 9
# 0.5482457805780274
# 0.3712787422334414
# 0.24473250212761186
# 0.5623392124487778
# Number of defined clusters: 16
# 0.36763506189625467
# 0.31811544822855553
# 0.0702254192518145
# 0.3767982208987432

# %%
for j in Xs:
    af = AffinityPropagation(damping=.9).fit(j)
    cluster_centers_indices = af.cluster_centers_indices_
    n_clusters2_ = len(cluster_centers_indices)
    labels2 = af.labels_
    print('Estimated number of clusters: {}'.format(n_clusters2_))
    print(metrics.silhouette_score(j, labels2, metric='euclidean'))
# Out:
# Estimated number of clusters: 67
# 0.4510302591211988
# Estimated number of clusters: 43
# 0.4657601121836545
# Estimated number of clusters: 54
# 0.49466748886298634
# Estimated number of clusters: 46
# 0.5268805817708097

# %%
bandwidth = estimate_bandwidth(data_norm, quantile=0.2, n_samples=2500)
ms = MeanShift(bandwidth=bandwidth, bin_seeding=True)
ms.fit(data_norm)    
labels = ms.labels_ # Extract cluster assignments for each data point.   
cluster_centers = ms.cluster_centers_  # Coordinates of the cluster centers.    
n_clusters_ = len(np.unique(labels)) # Count our clusters.

# %%
labels.shape
# Out:
# (31648,)

# %%
data['label'] = labels

# %%
plot_df = data.groupby('label')['age','official','gender'].mean().sort_values(by='age',ascending=False).reset_index()

# %%
plot_df.head()
# Out:
#    label        age    official    gender
# 0      0  43.791031  250.390430  0.491902
# 1      3  35.353333  159.077800  0.956667
# 2      1  32.059277  185.875012  1.000000
# 3      2  31.194737  134.796526  0.821053

# %%
plt.figure(figsize=(9,6))
sns.barplot(x='label',y='age',data=data)
plt.xlabel('Cluster')
plt.title('Average Age by Cluster')
# Out:
# C:\Users\godwinz\AppData\Local\Continuum\anaconda3\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval
# Text(0.5, 1.0, 'Average Age by Cluster')

# %%
plt.figure(figsize=(9,6))
sns.barplot(x='label',y='official',data=data)
plt.xlabel('Cluster')
plt.title('Average official by Cluster')
# Out:
# Text(0.5, 1.0, 'Average official by Cluster')

# %%
plt.figure(figsize=(15,9))
sns.lmplot(x='official',y='age',hue='label',data=data, lowess=True)
plt.show()

# %%
model = KMeans(n_clusters=5, random_state=None).fit(data_norm)
labels = model.labels_
data['labelk5'] = labels
data.head()
# Out:
#      10k  division    25k  gender  age  official  genderdiv     35k  overall  \
# 0  17.37         8  47.67       1   47     85.25          8   71.40        8
# 1  32.58         1  82.43       0   33    138.95          1  116.37       21
# 2  16.62         1  45.80       1   41     80.60          1   67.42        1
# 3  32.57         3  82.43       0   24    140.58          3  116.37       27
# 4  17.12         2  46.37       1   40     81.23          2   67.83        2
#
#    pace    30k     5k   half    20k  country     40k  label  labelk5
# 0  3.27  59.18   8.02  39.72  37.65       41   80.43      2        3
# 1  5.30  99.33  16.22  69.47  65.83       42  132.10      2        3
# 2  3.08  56.45   7.75  38.03  36.10       59   76.10      2        3
# 3  5.37  99.33  16.20  69.47  65.83       26  132.95      2        3
# 4  3.10  57.03   8.02  38.60  36.58       41   76.72      2        3

# %%
data.labelk5.hist()
plt.title('Runner count per cluster')
plt.show()

# %%
kmeanpdf = data.groupby('labelk5')['age','official','40k','25k','10k','genderdiv','gender'].mean()

# %%
plt.figure(figsize=(15,9))
sns.scatterplot(x='official',y='age',hue='labelk5',data=data)
plt.show()

# %% [markdown]
# As you can see, cluster 0 represents younger women, 1 is younger men, 2 are the top finishers 3 is older women and 4 is older men.
#
# I started the project by cleaning exploring and cleaning up the data. Then, I tried a few different clustering algorithms to create clusters in the data. For K means, the 4 cluster configuration looked the most promising (based on scores), however the means shift suggested 5 clusters for 3 of the 4 batches. The spectral clustering and affinity propagation methods did not appear to helpful, however further investigation with those methods may reveal other insights about the data. At the start,I chose mean-shift because i figured it would give 5 clusters, however, it gave 4, over and over again. I did visualize the results a but was not really satisfied. At that point I switched to K-means and declared 5 clusters, the results were better. As I pointed out above, the clusters descriminate well for gender, and then for performance.
